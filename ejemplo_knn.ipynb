# %% [markdown]
# ![banner.png](data:image/png;base64,...)

# %% [markdown]
# ## Paso 1: Importar librerías y crear conjunto de datos
#
# En este paso vamos a importar las librerías necesarias y crear nuestro conjunto de datos de frutas con sus características.

# %%
# Importar las bibliotecas necesarias (numpy, pandas, matplotlib.pyplot)
# También importar KNeighborsClassifier, train_test_split, accuracy_score, confusion_matrix, classification_report

# Crear el conjunto de datos original con las siguientes características:
# - Peso: [150, 170, 140, 130, 155, 180, 200, 120, 135, 145]
# - Tamaño: [7.0, 7.5, 6.5, 6.0, 7.2, 8.0, 8.5, 5.5, 6.2, 6.8]
# - Tipo: ['Manzana', 'Manzana', 'Manzana', 'Manzana', 'Manzana', 'Naranja', 'Naranja', 'Naranja', 'Naranja', 'Naranja']

# Crear un DataFrame con los datos originales

# Configurar semilla para reproducibilidad (np.random.seed(42))

# Crear datos adicionales para ampliar el conjunto:
# - Generar 10 elementos adicionales basados en los datos originales con variación aleatoria
# - Para Peso: usar los datos originales + variación entre -10 y 10
# - Para Tamaño: usar los datos originales + variación entre -0.5 y 0.5
# - Para Tipo: usar selección aleatoria de los tipos originales

# Crear DataFrame con los datos adicionales

# Combinar ambos DataFrames usando pd.concat()

# Mostrar las primeras 20 filas del DataFrame combinado

# %% [markdown]
# ## Paso 2: Separar datos para entrenamiento y prueba
#
# En este paso vamos a dividir nuestro conjunto de datos en características (X) y etiquetas (y), y luego separar en conjuntos de entrenamiento y prueba.

# %%
# Separar las características (X) y la etiqueta (y)
# X debe contener las columnas 'Peso' y 'Tamaño'
# y debe contener la columna 'Tipo'

# Dividir los datos en conjuntos de entrenamiento y prueba
# Usar train_test_split con test_size=0.3 y random_state=42

# %% [markdown]
# ## Paso 3: Entrenamiento del modelo KNN
#
# En este paso vamos a crear y entrenar nuestro modelo KNN con k=3 vecinos más cercanos.

# %%
# Crear y entrenar el modelo KNN
# Usar KNeighborsClassifier con n_neighbors=3
# Entrenar el modelo con X_train y y_train usando el método fit()

# %% [markdown]
# ## Paso 4: Predicción y evaluación del modelo
#
# En este paso vamos a usar el modelo entrenado para hacer predicciones y evaluar su rendimiento usando métricas como precisión, matriz de confusión y reporte de clasificación.

# %%
# Hacer predicciones sobre el conjunto de prueba
# Usar el método predict() del modelo knn con X_test

# Evaluar el modelo calculando:
# 1. Accuracy usando accuracy_score(y_test, y_pred)
# 2. Matriz de confusión usando confusion_matrix(y_test, y_pred)
# 3. Reporte de clasificación usando classification_report(y_test, y_pred, zero_division=0)

# Mostrar los resultados con print()

# %% [markdown]
# ## Paso 5: Visualización de los resultados
#
# En este paso vamos a crear un gráfico que muestre los datos de entrenamiento y las predicciones del modelo para visualizar cómo funciona la clasificación KNN.

# %%
# Crear visualización de los datos y la clasificación
# Configurar el tamaño de la figura con plt.figure(figsize=(10, 6))

# Crear scatter plot para los puntos de entrenamiento:
# - X: X_train['Peso'], Y: X_train['Tamaño']
# - Colores: rojo para 'Manzana', naranja para 'Naranja' (usar diccionario de colores)
# - Label: 'Datos de Entrenamiento'

# Crear scatter plot para los puntos de prueba:
# - X: X_test['Peso'], Y: X_test['Tamaño'] 
# - Colores: usar y_pred para los colores (rojo para 'Manzana', naranja para 'Naranja')
# - Marker: 'x'
# - Label: 'Datos de Prueba'

# Configurar etiquetas y título:
# - xlabel: 'Peso'
# - ylabel: 'Tamaño' 
# - title: 'Clasificación de Frutas con KNN'

# Mostrar leyenda y gráfico con plt.legend() y plt.show()

# %% [markdown]
# ### Explicación de los Resultados
#
# En el gráfico anterior, los puntos circulares representan las frutas del conjunto de entrenamiento, donde las manzanas están en rojo y las naranjas en naranja. Los puntos en forma de "x" representan las frutas del conjunto de prueba, que han sido clasificadas por el modelo.
#
# El modelo KNN ha sido capaz de clasificar correctamente la mayoría de las frutas basándose en su proximidad a los puntos de entrenamiento. La precisión obtenida y la matriz de confusión nos muestran cuán bien funciona el modelo para este conjunto de datos. Un valor de `k=3` significa que el modelo toma en cuenta los 3 vecinos más cercanos para tomar la decisión final de clasificación.
