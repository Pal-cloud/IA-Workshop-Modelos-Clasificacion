# %% [markdown]
# ![banner.png](data:image/png;base64,...)

# %% [markdown]
# ### Paso 1: Importa las librerías

# %%
# Paso 1: Importa las librerías necesarias
# Importa pandas para manejo de datos
# Importa DecisionTreeClassifier y plot_tree de sklearn.tree
# Importa matplotlib.pyplot para visualizaciones

# Tu código aquí:

# %% [markdown]
# ### Paso 2: cargamos el dataset ficticio

# %%
# Paso 2: Crear el conjunto de datos
# Crea un diccionario llamado 'data' con las siguientes claves:
# - 'Tiene_jardin': [1, 1, 0, 0, 1, 0, 0, 1]
# - 'Tiene_hijos': [0, 1, 1, 0, 0, 1, 0, 1]  
# - 'Es_alergico': [0, 0, 0, 1, 1, 1, 0, 0]
# - 'Adopta_perro': [1, 1, 1, 0, 1, 0, 0, 1]

# Tu código aquí:


# Crear un DataFrame con los datos y mostrar los primeros registros
# Tu código aquí:

# %% [markdown]
# ### Paso 3: Separa las variables independientes de la dependiente en X e Y

# %%
# Paso 3: Separar las características (X) de la variable objetivo (y)
# X debe contener las columnas: 'Tiene_jardin', 'Tiene_hijos', 'Es_alergico'
# y debe contener la columna: 'Adopta_perro'

# Tu código aquí:

# %% [markdown]
# ### Paso 4: Entrena el modelo

# %%
# Paso 4: Crear y entrenar el modelo de árbol de decisión
# Crea un objeto DecisionTreeClassifier con criterion='entropy' y random_state=0
# Entrena el modelo usando el método fit() con X e y

# Tu código aquí:

# %% [markdown]
# ### Paso 5: Visualiza el árbol de desición

# %%
# Paso 5: Visualizar el árbol de decisión
# Crea una figura con tamaño (16,10)
# Usa plot_tree con los siguientes parámetros:
# - feature_names=X.columns
# - class_names=['No Adopta', 'Adopta']  
# - filled=True
# - rounded=True
# - fontsize=12
# No olvides usar plt.show() al final

# Tu código aquí:
