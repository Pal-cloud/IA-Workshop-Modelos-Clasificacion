# %% [markdown]
# ![banner.png](data:image/png;base64,...)

# %% [markdown]
# ### Paso 1: Importar librerías necesarias

# %%
# Paso 1: Importar las librerías necesarias
# Importa numpy como np
# Importa matplotlib.pyplot como plt  
# Desde sklearn importa svm
# Desde sklearn.model_selection importa train_test_split

# Tu código aquí:

# %% [markdown]
# ### Paso 2: Generar datos simulados

# %%
# Paso 2: Generar datos simulados
# Establece la semilla aleatoria en 0 usando np.random.seed(0)
# Crea X usando np.r_ combinando:
#   - np.random.randn(20, 2) * 2 + [5, 5] (primera clase)
#   - np.random.randn(20, 2) * 2 + [10, 10] (segunda clase)
# Crea Y con [0] * 20 + [1] * 20 (etiquetas de clase)

# Tu código aquí:

# %% [markdown]
# ### Paso 3: Dividir datos en entrenamiento y prueba

# %%
# Paso 3: Dividir los datos en entrenamiento y prueba
# Usa train_test_split para dividir X e Y
# Parámetros: test_size=0.3, random_state=42
# Variables de salida: X_train, X_test, Y_train, Y_test

# Tu código aquí:

# %% [markdown]
# ### Paso 4: Entrenar el modelo SVM lineal

# %%
# Paso 4: Entrenar el modelo SVM lineal
# Crea un modelo SVM usando svm.SVC(kernel='linear')
# Entrena el modelo usando fit() con X_train e Y_train
# Guarda el modelo en una variable llamada 'model'

# Tu código aquí:

# %% [markdown]
# ### Paso 5: Visualizar los datos y la frontera de decisión

# %%
# Paso 5: Visualizar los datos y la frontera de decisión
# 1. Crea un scatter plot de X con colores Y usando cmap='winter'
# 2. Obtén los límites del gráfico (xlim, ylim) usando ax.get_xlim() y ax.get_ylim()
# 3. Crea una malla de puntos usando np.linspace y np.meshgrid
# 4. Evalúa el modelo en la malla usando model.decision_function()
# 5. Dibuja los contornos para levels=[-1, 0, 1] 
# 6. Marca los vectores de soporte con círculos
# 7. Agrega título, etiquetas de ejes y muestra el gráfico

# Tu código aquí:

# %% [markdown]
# ### Paso 6: Generar datos para SVM polinómico

# %%
# Paso 6: Generar datos para SVM polinómico
# Repite la generación de datos del Paso 2
# (mismo código para tener consistencia en la comparación)

# Tu código aquí:

# %% [markdown]
# ### Paso 7: Dividir datos y entrenar SVM polinómico

# %%
# Paso 7: Dividir datos y entrenar SVM polinómico
# 1. Divide los datos nuevamente usando train_test_split
# 2. Crea un modelo SVM con kernel='poly' 
# 3. Entrena el modelo con los datos de entrenamiento

# Tu código aquí:

# %% [markdown]
# ### Paso 8: Visualizar SVM polinómico

# %%
# Paso 8: Visualizar SVM polinómico
# Repite la misma visualización del Paso 5
# Esto te permitirá comparar la frontera lineal vs polinómica
# Observa cómo cambia la forma de la frontera de decisión

# Tu código aquí:
